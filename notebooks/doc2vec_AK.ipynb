# %%
import pandas as pd
import numpy as np
import gensim
from nltk import RegexpTokenizer
from nltk.corpus import stopwords

# %%
data = pd.read_pickle('data_clean_4cols.pickle')
candidate_data = pd.DataFrame()
candidate_data = (data
                  .drop(['id', 'message'], axis=1)
                  .drop_duplicates('from_name')
                  .set_index('from_name'))

# %%
G = data.groupby('from_name',as_index=False)['message'].apply(' '.join)
candidate_data['Partei_ABK']=G.values
candidate_data.columns = ['text']

# %%
tokenizer = RegexpTokenizer(r'\w+')
stopword_set = set(stopwords.words('german'))
#This function does all cleaning of data using two objects above
def nlp_clean(data):
    new_data = []
    for d in data:
        new_str = d.lower()
        dlist = tokenizer.tokenize(new_str)
        dlist = list(set(dlist).difference(stopword_set))
        new_data.append(dlist)
    return new_data

# %%
candidate_data['text'] = candidate_data['text'].str.replace('\d+', '')#deleting nums

# %%
candidate_data['text']= nlp_clean(candidate_data['text'])

# %%
candidate_data #some candidates have party names next to their names
# Out:
#                                                                                               text
# from_name
# Valentin Abel                                    [engagierten, volkshaus, direktkandidaten, ver...
# Dr. Michael von Abercron                         [verhöhnt, interessant, rnk, osten, gesicht, g...
# Grigorios Aggelidis                              [kraft, engagierten, reparieren, brügermeister...
# Diyar Agu                                        [form, courage, kraft, überfluss, arbeitsplätz...
# Gökay Akbulut DIE LINKE                          [löst, interessant, rauch, hinsicht, regime, r...
# Rolf Albach                                      [hervorgeholt, anschauen, mdep, bildungszentru...
# Stephan Albani MdB                               [courage, systeme, anschauen, regen, lautete, ...
# Katrin Albsteiger                                [kamsdorf, aufgefordert, kraft, gesponsert, se...
# Daniel Alff                                      [form, wahres, löst, einwirkung, kraft, arbeit...
# Renata Alt                                       [form, kraft, kreisjugendring, regen, stattgef...
# Norbert Altenkamp                                [form, courage, kraft, moskauer, regime, utag,...
# Peter Altmaier                                   [rüstungsexport, arbeit, reaktionäre, karte, s...
# Philipp Amthor                                   [form, engagierten, kleiner, arbeit, werbung, ...
# Luise Amtsberg                                   [hildmann, form, interessant, engagierten, hän...
# Christine Anderson                               [setzten, direktkandidaten, doppelpack, rfo, z...
# Kerstin Andreae                                  [form, verblüfft, kraft, linder, entweder, arb...
# Eva von Angern                                   [form, interessant, kraft, entweder, aufgeford...
# Niels Annen                                      [form, männern, kraft, entweder, interessant, ...
# Ralf Armbrüster                                  [wertwiesen, ausschließt, form, kraft, höchste...
# Özden Ates                                       [löst, kraft, regen, selben, best, oft, sozial...
# Kerstin Auerbach, DIE LINKE.                     [kraft, direktkandidaten, staatsausgaben, oft,...
# Artur Auernhammer                                [löst, auge, direktkandidaten, bellini, karte,...
# Dennis Augustin                                  [wahres, interessant, kraft, entweder, inwiefe...
# Marcel Aulila                                    [form, wahres, interessant, kraft, kleiner, di...
# Peter Aumer                                      [reale, engagierten, kraft, enten, mdep, ausse...
# Jeannette Auricht                                [gastrennung, verblüfft, mendigerinnen, engagi...
# Bela Bach                                        [form, interessant, engagierten, größe, schich...
# Tobias B. Bacherle                               [hilfsaktion, männern, osten, kleiner, וגרוריו...
# Lisa Badum                                       [form, kraft, berichteten, selben, osten, laut...
# Heike Baehrens                                   [knödel, engagierten, großartiger, größe, milc...
# ...                                                                                            ...
# Herbert Woerlein                                 [stiefelnazis, form, siegen, interessant, kraf...
# Dr. Alexander Wolf                               [wahres, auge, vorsorge, regime, sprache, zuve...
# Armin Wolf                                       [form, auge, wahres, interessant, zukunftwirda...
# Stefan Wolf                                      [interessant, sprache, teuer, fußgängerzone, k...
# Klaus Wolframm                                   [islamuniversität, ausbildungsplatz, interessa...
# Gereon Wolters                                   [listenkandidat, hob, engagierten, kraft, arbe...
# Jörn Wunderlich                                  [löst, form, nachkommen, kraft, wäschereibetri...
# Gülistan Yüksel - Miteinander. Für Deutschland.  [form, gelaunten, unternehmerverbandes, hinsic...
# Oliver Zander                                    [siegen, kraft, siegerlandflughafens, weindorf...
# Hubertus Zdebel                                  [form, interessant, kraft, entweder, höchstem,...
# Emmi Zeulner                                     [upcycling, sorry, basteln, plakat, sehen, geh...
# Gerhard Zickenheiner                             [engagierten, hc_location, privatisierung, arb...
# Dagmar Ziegler MdB                               [ferdinand, arbeitsplätzen, musbach, oft, mehr...
# Kay-Uwe Ziegler                                  [kraft, specials, regime, osten, multimilliona...
# Tristan Zielinski                                [vorbereitungstreffen, männern, entweder, arbe...
# Paul Ziemiak                                     [studienberatung, courage, engagierten, kraft,...
# Stefan Zierke                                    [taxikunden, regen, ausgaben, dach, rechnung, ...
# Benjamin Zilles                                  [interessant, regime, dieder, wegberg, innen, ...
# Matthias Zimmer                                  [form, löst, entweder, überfluss, abgeschirmte...
# Christoph Zimmermann- Unsere Zukunft ist Jetzt   [form, wehrbeauftragten, interessant, kraft, r...
# Jens Zimmermann                                  [kraft, entweder, engagierten, inwiefern, ausg...
# Pia Zimmermann                                   [tokography, anselm, huber, ramersdorf, sprach...
# Sabine Zimmermann                                [männern, kraft, zusammenhalten, osten, direkt...
# Alexander Zink                                   [form, anschauen, netzwerke, pflegt, arbeitspl...
# Gudrun Zollner, MdB a.D.                         [bitte, angegriffen, anschauen, ja, bürger, fu...
# Dirk-Ulrich Mende                                [engagierten, kraft, beich, tollem, freizeithe...
# Manuel Paschke                                   [form, männern, interessant, humanismus, laute...
# Dr. Daniela De Ridder                            [oberpfalz, sprache, fußgängerzone, direktkand...
# Björn Simon                                      [form, sosyal, pergamonmuseum, männern, kraft,...
# Waldemar Westermayer                             [nationalen, kraft, regime, umgehend, kleiner,...
#
# [1001 rows x 1 columns]

# %%
#ok, so now we need to prepare an object for word2vec
class LabeledLineSentence(object):
    def __init__(self, doc_list, labels_list):
        self.labels_list = list(labels_list)
        self.doc_list = doc_list
    def __iter__(self):
        for idx, doc in enumerate(self.doc_list):
              yield gensim.models.doc2vec.LabeledSentence(doc, [self.labels_list[idx]])

# %%
ourobject = LabeledLineSentence(candidate_data['text'], candidate_data.index)

# %%
model = gensim.models.Doc2Vec(size=300, min_count=0, alpha=0.025, min_alpha=0.025)
model.build_vocab(ourobject)
#training of model
for epoch in range(2):
    model.train(ourobject, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.002
    model.min_alpha = model.alpha
#saving the created model
model.save('doc2vec.model')

# %%
model = gensim.models.Doc2Vec(size=300, min_count=0, alpha=0.025, min_alpha=0.025)
model.build_vocab(labeled_docs)
#training of model
for epoch in range(2):
    model.train(labeled_docs, total_examples=model.corpus_count, epochs=model.iter)
    model.alpha -= 0.002
    model.min_alpha = model.alpha
    model.train(labeled_docs, total_examples=model.corpus_count, epochs=model.iter)
#saving the created model
model.save('doc2vec.model')
# Out:
# 2017-12-25 16:02:52 WARNING Each 'words' should be a list of words (usually unicode strings). First 'words' here is instead plain <class 'str'>.

# %%
def tsne(model):
    doc_2d = []

    for doc in model.docvecs:
        doc_2d.append(TSNE().fit_transform(doc).tolist()[0])

    return np.asarray(doc_2d)   # return ndarray


def plot_model(doc_2d, labels):
    plt.figure(num=1, figsize=(80, 80), facecolor="w", edgecolor="k")

    for label, doc in zip(labels, doc_2d):
        plt.plot(doc[0], doc[1], ".")
        plt.annotate(label, (doc[0], doc[1]))

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-e4ab557759dd> in <module>()
# ----> 1 model.most_similar ("gerade")
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/word2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1338         Refer to the documentation for `gensim.models.KeyedVectors.most_similar`
#    1339         """
# -> 1340         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1341
#    1342     def wmdistance(self, document1, document2):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     338                 mean.append(weight * word)
#     339             else:
# --> 340                 mean.append(weight * self.word_vec(word, use_norm=True))
#     341                 if word in self.vocab:
#     342                     all_words.add(self.vocab[word].index)
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     286             return result
#     287         else:
# --> 288             raise KeyError("word '%s' not in vocabulary" % word)
#     289
#     290     def most_similar(self, positive=None, negative=None, topn=10, restrict_vocab=None, indexer=None):
#
# KeyError: "word 'gerade' not in vocabulary"

# %%
candidate_data[:1]
# Out:
#               Partei_ABK                                           messages
# from_name
# Valentin Abel        FDP  Gerade einmal 9.000 Anträge auf die Kaufprämie...
